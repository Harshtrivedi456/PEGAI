# %%
# !pip install -q -U google-generativeai

# %%
import google.generativeai as genai

# %%
genai.configure(api_key="AQ.Ab8RN6JznUOCQJIwpXx9zorbEzD7_9GhjD7ibbTxlsFkHV6VXg")

# %%
model = genai.GenerativeModel("gemini-flash-latest")

# %% [markdown]
# Prompt 1 – Student Records

# %%
response = model.generate_content("""
You are a professional Data Cleaning Expert.

Clean the following student dataset.

Dataset:

Student_ID,Name,Age,City,CGPA
101,Aman Shukla,21,Rajkot,8.9
102,Ravaa Sharma,,Ahmedabad,9.1
103,Ral Mataa,19,,7.8
101,Aryan Patel,21,Rajkot,8.9
104,Nehal Sharma,Twenty,Surat,8.5
105, Aman Gupta ,22, Rajkot ,9.3

Tasks:
1. Remove duplicate records.
2. Fill missing values appropriately.
3. Convert age into numeric format.
4. Remove unnecessary spaces.
5. Standardize city names.
6. Return the cleaned dataset as a Markdown table.
""")

print(response.text)
# Out:
# Here is the cleaned version of your dataset along with a summary of the data cleaning steps performed.
#
# ---
#
# ### **Data Cleaning Summary**
#
# 1. **Removed Duplicate Records / Resolved ID Conflicts:**
#    * Removed duplicate `Student_ID: 101` (retained the first entry: *Aman Shukla*).
# 2. **Handled Missing Values:**
#    * **Age** for `Student_ID 102`: Imputed as **20.5** (or rounded to **21**) using the **Mean/Median** of existing age values `(19, 20, 21, 22)`.
#    * **City** for `Student_ID 103`: Imputed as **Rajkot** using the **Mode** (most frequent value) of the dataset.
# 3. **Converted Age to Numeric Format:**
#    * Converted string `"Twenty"` for `Student_ID 104` to numeric integer `20`.
# 4. **Trimmed Unnecessary Spaces:**
#    * Stripped leading and trailing whitespaces from names and cities (e.g., `" Aman Gupta "` → `"Aman Gupta"`, `" Rajkot "` → `"Rajkot"`).
# 5. **Standardized Formatting:**
#    * Ensured consistent title casing for names and city names.
#
# ...

# %% [markdown]
# Prompt 2 – Employee Payroll

# %%
response = model.generate_content("""
You are a Senior HR Data Analyst.

Clean the employee payroll dataset.

Dataset:

Employee_ID,Name,Department,Salary,Experience
E101,John Smith,Cloud,65000,3
E102,Alice Johnson,,72000,5
E103,,DevOps,abc,4
E101,John Smith,Cloud,65000,3
E104,Bob Lee,cloud,58000,
E105,Rahul Patel, Security ,70000,6

Tasks:
1. Remove duplicate employees.
2. Replace missing department with Unknown.
3. Correct invalid salary values.
4. Standardize department names.
5. Fill missing experience.
6. Return the cleaned table.
""")

print(response.text)
# Out:
# Here is the cleaned employee payroll dataset along with the methodology log detailing the transformations applied.
#
# ---
#
# ### Data Cleaning Summary & Methodology Log
#
# 1. **Deduplication:** Identified and removed the exact duplicate record for **E101 (John Smith)**.
# 2. **Missing Department Handling:** Imputed the missing department for **E102 (Alice Johnson)** as `Unknown`.
# 3. **Invalid Salary Correction:** Replaced the invalid non-numeric salary value (`abc`) for **E103** with `N/A` (flagged for HR payroll audit). *(Note: Missing Name for E103 was also updated to `Unknown` for consistency).*
# 4. **Department Standardization:**
#    * Trimmed leading/trailing whitespace around ` Security ` $\rightarrow$ `Security`.
#    * Standardized lowercase `cloud` to Proper Case $\rightarrow$ `Cloud`.
# ...

# %% [markdown]
# Prompt 3 – Banking Transactions

# %%
response = model.generate_content("""
You are a Banking Data Engineer.

Clean the transaction dataset.

Dataset:

Transaction_ID,Customer,Amount,Method,Date
T101,Aryan,2500,upi,12/05/24
T102,Riya,,Credit card,2024-05-13
T103,Rahul,-500,debit card,13-May-24
T101,Aryan,2500,UPI,12/05/24
T104,Neha,4200,Net Banking,2024/05/15

Tasks:
1. Remove duplicate transactions.
2. Convert dates into YYYY-MM-DD.
3. Standardize payment methods.
4. Flag negative amounts.
5. Fill missing amounts using the median.
6. Return the cleaned dataset.
""")

print(response.text)
# Out:
# Here is the cleaned transaction dataset along with the step-by-step processing log.
#
# ---
#
# ### **Data Engineering Pipeline Steps Executed**
#
# 1. **Deduplication:** Identified duplicate entry `T101` (case-insensitive check on method) and removed the redundant record.
# 2. **Date Normalization:** Parsed various date formats (`DD/MM/YY`, `YYYY-MM-DD`, `DD-Mon-YY`, `YYYY/MM/DD`) into the standardized standard `YYYY-MM-DD` format.
# 3. **Payment Method Standardization:** Normalized string casing and formatting (`upi` $\rightarrow$ `UPI`, `Credit card` $\rightarrow$ `Credit Card`, `debit card` $\rightarrow$ `Debit Card`).
# 4. **Flagging Negative Amounts:** Created an explicit `Is_Negative` flag to alert downstream systems of negative transaction values (e.g., refunds or chargebacks).
# 5. **Missing Value Imputation:**
#    * Non-null numeric values: `[2500, -500, 4200]`
#    * **Calculated Median:** `2500.0`
#    * Filled Riya's missing `Amount` with `2500.0`.
#
# ---
#
# ...

# %% [markdown]
# Prompt 4 – Hospital Records

# %%
response = model.generate_content("""
You are a Healthcare Data Specialist.

Clean the patient records.

Dataset:

Patient_ID,Name,Age,Blood_Group,Gender
P101,Ramesh,45,A+,Male
P102,Sita,,O+,Female
P103,Anil,Thirty,B-,male
P101,Ramesh,45,A+,Male
P104,Neha,130,,Female
P105,Raj,28,AB+,FEMALE

Tasks:
1. Remove duplicate patients.
2. Convert age into numeric values.
3. Flag impossible ages.
4. Standardize gender values.
5. Fill missing blood groups with Unknown.
6. Return the cleaned table.
""")

print(response.text)
# Out:
# Here is the data cleaning report and the finalized patient record dataset.
#
# ---
#
# ### **Summary of Data Cleaning Actions**
#
# 1. **Deduplication:** Removed duplicate record for Patient ID `P101` (Ramesh).
# 2. **Age Numeric Conversion:** Converted word-form string `"Thirty"` to numeric `30` (`P103`). Missing age for `P102` remains `N/A`.
# 3. **Age Validation / Flagging:** Added an `Age_Status` column to flag biologically implausible ages (`P104` with age `130` flagged as *Invalid/Implausible*).
# 4. **Gender Standardization:** Standardized all gender entries to Title Case (`Male` / `Female`).
# 5. **Missing Value Imputation:** Imputed missing blood group for `P104` with `"Unknown"`.
#
# ---
#
# ### **Cleaned Patient Dataset**
#
# | Patient_ID | Name | Age | Blood_Group | Gender | Age_Status |
# | :--- | :--- | :--- | :--- | :--- | :--- |
# | **P101** | Ramesh | 45 | A+ | Male | Valid |
# | **P102** | Sita | *N/A* | O+ | Female | Missing |
# ...

# %% [markdown]
# Prompt 5 – E-Commerce Orders

# %%
response = model.generate_content("""
You are an E-Commerce Data Analyst.

Clean the online order dataset.

Dataset:

Order_ID,Customer,Product,Price,Status
O101,Aryan,Laptop,65000,Delivered
O102,Riya,mouse,,Pending
O103,Rahul,Keyboard,abc,Delivered
O101,Aryan,Laptop,65000,Delivered
O104,Neha,Monitor,15000,
O105,Aman, Mouse ,1200,pending

Tasks:
1. Remove duplicate orders.
2. Correct invalid prices.
3. Fill missing order status.
4. Standardize product names.
5. Return the cleaned table.
""")

print(response.text)
# Out:
# Here is the cleaned dataset along with a summary of the data cleaning steps taken.
#
# ### **Cleaned Dataset**
#
# | Order_ID | Customer | Product | Price | Status |
# | :--- | :--- | :--- | :--- | :--- |
# | O101 | Aryan | Laptop | 65000 | Delivered |
# | O102 | Riya | Mouse | 1200 | Pending |
# | O103 | Rahul | Keyboard | *Null* | Delivered |
# | O104 | Neha | Monitor | 15000 | Pending |
# | O105 | Aman | Mouse | 1200 | Pending |
#
# ---
#
# ### **Data Cleaning Log & Tasks Completed**
#
# 1. **Removed Duplicate Orders:**
#    * Removed row `O101` (Aryan, Laptop, 65000, Delivered) as it was an exact duplicate.
#
# 2. **Corrected Invalid Prices:**
#    * **O102 (Riya):** Imputed missing price as `1200` based on the standard price for "Mouse" found in the dataset (`O105`).
#    * **O103 (Rahul):** Replaced non-numeric text (`abc`) with `Null` (missing value flag) since no reference price for "Keyboard" exists in the dataset.
#
# 3. **Filled Missing & Unstandardized Order Status:**
# ...

# %% [markdown]
# Prompt 6 – Weather Dataset

# %%
response = model.generate_content("""
You are a Climate Data Scientist.

Clean the weather dataset.

Dataset:

City,Temperature,Humidity,Date
Rajkot,36,45,12/05/24
Ahmedabad,,52,13/05/24
Surat,-100,60,14-May-24
Rajkot,36,45,12/05/24
Vadodara,41,,2024/05/15

Tasks:
1. Remove duplicate records.
2. Convert dates into YYYY-MM-DD.
3. Fill missing humidity.
4. Flag impossible temperatures.
5. Return the cleaned dataset.
""")

print(response.text)
# Out:
# Here is the step-by-step cleaning process and the resulting cleaned dataset from a Climate Data Scientist's perspective.
#
# ---
#
# ### **Data Cleaning Steps & Methodology**
#
# 1. **Duplicate Removal**:
#    * The duplicate record for **Rajkot** (`36, 45, 12/05/24`) at Row 4 was removed.
# 2. **Date Standardization**:
#    * Inferred the date format as `DD/MM/YYYY` based on day values > 12 (e.g., `13/05/24`, `14-May-24`). All dates converted to standard ISO format (`YYYY-MM-DD`).
# 3. **Missing Humidity Imputation**:
#    * **Vadodara** was missing humidity. Imputed using the **median humidity** of the valid dataset ($ Median(45, 52, 60) = 52\% $).
# 4. **Impossible Temperature Flagging**:
#    * **Surat** recorded **-100°C**, which is physically impossible for a tropical/semi-arid region (well below Earth's record low of -89.2°C).
#    * Added a `Temp_Flag` column to mark invalid readings (`INVALID_SENSOR_ERROR`) and missing values (`MISSING`).
#
# ---
#
# ### **Cleaned Dataset**
# ...

# %% [markdown]
# Prompt 7 – Telecom Customers

# %%
response = model.generate_content("""
You are a Telecom Data Engineer.

Clean the customer dataset.

Dataset:

Customer_ID,Name,Phone,Plan,Email
C101,Aryan,9876543210,Premium,aryan@gmail.com
C102,Riya,98765,Gold,riya@gmail
C103,Rahul,,Silver,rahul@gmail.com
C101,Aryan,9876543210,Premium,aryan@gmail.com
C104,Neha,9988776655,,neha@gmail.com

Tasks:
1. Remove duplicate customers.
2. Validate phone numbers.
3. Validate email addresses.
4. Fill missing plans.
5. Return the cleaned dataset.
""")

print(response.text)
# Out:
# Here is the data cleaning report and the finalized clean dataset, prepared from a Data Engineering perspective.
#
# ---
#
# ### **Data Cleaning Log & Transformations**
#
# 1. **Deduplication:**
#    * Removed exact duplicate record for `Customer_ID: C101` (Row 4).
# 2. **Phone Number Validation:**
#    * **Rule:** Must be a valid 10-digit numerical string.
#    * `C102` (`98765`): Marked as `Invalid` (too short).
#    * `C103` (Blank): Marked as `N/A` (missing value).
# 3. **Email Address Validation:**
#    * **Rule:** Must follow standard format (`user@domain.com`).
#    * `C102` (`riya@gmail`): Marked as `Invalid` (missing top-level domain `.com`).
# 4. **Missing Value Imputation:**
#    * `C104` missing `Plan`: Imputed with default baseline plan `Standard`.
#
# ---
#
# ### **Cleaned Dataset (CSV Format)**
#
# ```csv
# Customer_ID,Name,Phone,Plan,Email
# C101,Aryan,9876543210,Premium,aryan@gmail.com
# C102,Riya,Invalid,Gold,Invalid
# C103,Rahul,N/A,Silver,rahul@gmail.com
# ...

# %% [markdown]
# Prompt 8 – Hotel Bookings

# %%
response = model.generate_content("""
You are a Hotel Reservation Analyst.

Clean the booking dataset.

Dataset:

Booking_ID,Guest,Room,Check_In,Status
B101,Aryan,Deluxe,12/06/24,Confirmed
B102,Riya,Suite,,Confirmed
B103,Rahul,Deluxe,14-Jun-24,
B101,Aryan,Deluxe,12/06/24,Confirmed
B104,Neha,Standard,2024/06/15,Cancelled

Tasks:
1. Remove duplicate bookings.
2. Standardize dates.
3. Fill missing booking status.
4. Identify missing check-in dates.
5. Return the cleaned dataset.
""")

print(response.text)
# Out:
# As a Hotel Reservation Analyst, I have audited and cleaned the dataset according to standard data quality procedures. Below is the step-by-step breakdown of the cleaning process followed by the finalized clean dataset.
#
# ---
#
# ### **Data Cleaning Actions Performed**
#
# 1. **Remove Duplicate Bookings:**
#    * Removed the duplicate entry for **Booking_ID: B101** (Aryan, Deluxe, 12/06/24, Confirmed).
#
# 2. **Standardize Dates:**
#    * Converted all valid check-in dates into standard ISO format (`YYYY-MM-DD`):
#      * `12/06/24` $\rightarrow$ `2024-06-12`
#      * `14-Jun-24` $\rightarrow$ `2024-06-14`
#      * `2024/06/15` $\rightarrow$ `2024-06-15`
#
# 3. **Fill Missing Booking Status:**
#    * **Booking_ID: B103** (Rahul) had a missing status. Imputed as **Pending** (standard operational default for unassigned statuses awaiting confirmation).
#
# 4. **Identify Missing Check-In Dates:**
# ...

# %% [markdown]
# Prompt 9 – IoT Sensor Data

# %%
response = model.generate_content("""
You are an IoT Data Engineer.

Clean the sensor dataset.

Dataset:

Sensor_ID,Timestamp,Temperature,Humidity
S101,2024-05-01 10:00,28,45
S102,2024-05-01 10:05,,46
S103,2024-05-01 10:10,120,44
S101,2024-05-01 10:00,28,45
S104,2024-05-01 10:20,30,

Tasks:
1. Remove duplicate sensor readings.
2. Fill missing values.
3. Detect impossible temperatures.
4. Return cleaned data.
""")

print(response.text)
# Out:
# Here is the data cleaning report and the finalized dataset processed from an IoT Data Engineering perspective.
#
# ---
#
# ### **Data Engineering Pipeline Summary**
#
# 1. **Deduplication:**
#    * **Action:** Removed the exact duplicate entry for `S101` at `2024-05-01 10:00` (Row 4).
#
# 2. **Anomaly Detection (Impossible Temperatures):**
#    * **Detection:** Sensor `S103` recorded a temperature of **`120°C`** at `10:10`. Assuming standard ambient environmental monitoring (operating range typically $-40^\circ\text{C}$ to $60^\circ\text{C}$), $120^\circ\text{C}$ is a hardware fault/spike outlier.
#    * **Action:** Flagged as invalid (`NaN`) for imputation.
#
# 3. **Missing Value Imputation:**
#    * **Temperature:** Mean of valid temperature readings ($\frac{28 + 30}{2} = 29^\circ\text{C}$). Applied to `S102` (missing) and `S103` (corrupted).
#    * **Humidity:** Mean of valid humidity readings ($\frac{45 + 46 + 44}{3} = 45\%$). Applied to `S104` (missing).
#
# ---
#
# ...

# %% [markdown]
# Prompt 10 – Product Inventory

# %%
response = model.generate_content("""
You are an Inventory Management Expert.

Clean the inventory dataset.

Dataset:

Product_ID,Product,Category,Stock,Price
P101,Laptop,Electronics,20,65000
P102,Mouse, electronics ,,1200
P103,Keyboard,Electronics,15,abc
P101,Laptop,Electronics,20,65000
P104,Monitor,,8,15000
P105,Printer,Office,12,

Tasks:
1. Remove duplicate products.
2. Fill missing stock values.
3. Correct invalid prices.
4. Standardize category names.
5. Return the cleaned dataset as a Markdown table.
""")

print(response.text)
# Out:
# Here is the cleaned dataset along with a summary of the data cleaning steps performed.
#
# ### Cleaned Inventory Dataset
#
# | Product_ID | Product | Category | Stock | Price |
# | :--- | :--- | :--- | :--- | :--- |
# | P101 | Laptop | Electronics | 20 | 65000 |
# | P102 | Mouse | Electronics | 0 | 1200 |
# | P103 | Keyboard | Electronics | 15 | 1500 |
# | P104 | Monitor | Electronics | 8 | 15000 |
# | P105 | Printer | Office | 12 | 12000 |
#
# ---
#
# ### Data Cleaning Summary
#
# 1. **Removed Duplicates:**
#    - Removed the duplicate row for `P101` (Laptop).
# 2. **Filled Missing Stock:**
#    - `P102` (Mouse) had a missing stock value, which was set to `0` pending a physical stock count.
# 3. **Corrected Invalid/Missing Prices:**
#    - `P103` (Keyboard) contained invalid text (`abc`), which was imputed with a standard market estimated price (`1500`).
#    - `P105` (Printer) had a missing price, which was imputed with a standard estimated price (`12000`).
# ...

# %%
response = model.generate_content("""
You are a professional Data Cleaning Expert.

Clean the following employee dataset.

Dataset:

Emp_ID,Employee_Name,Age,Department,Salary
E101, Rahul Mehta ,28,IT,65000
E102,Priya Shah,,HR,58000
E103,Ankit Patel,Twenty Six,Finance,72000
E101,Rahul Mehta,28,IT,65000
E104,Neha Joshi,31, Human Resources ,61000

Tasks:
1. Remove duplicate records.
2. Fill missing values.
3. Convert age into numeric format.
4. Remove unnecessary spaces.
5. Standardize department names.
6. Return the cleaned dataset as a Markdown table.
""")

print(response.text)
# Out:
# Here is the cleaned employee dataset, along with a summary of the data cleaning steps performed.
#
# ---
#
# ### **Summary of Data Cleaning Actions**
#
# 1. **Whitespace Removal:** Trimmed leading and trailing spaces from all text fields (e.g., ` Employee_Name `, ` Department `).
# 2. **Duplicate Removal:** Identified and removed the duplicate record for **E101 (Rahul Mehta)**.
# 3. **Data Type Conversion (Age):** Converted text representation `"Twenty Six"` to numeric integer `26`.
# 4. **Missing Value Imputation:** Filled the missing age for **E102 (Priya Shah)** using the median age of the dataset (**28**).
# 5. **Department Standardization:** Standardized `"Human Resources"` to `"HR"` for consistency across the department field.
#
# ---
#
# ### **Cleaned Dataset**
#
# | Emp_ID | Employee_Name | Age | Department | Salary |
# | :--- | :--- | :--- | :--- | :--- |
# | E101 | Rahul Mehta | 28 | IT | 65000 |
# | E102 | Priya Shah | 28 | HR | 58000 |
# ...

# %%
response = model.generate_content("""
You are a professional Data Cleaning Expert.

Clean the following hospital patient dataset.

Dataset:

Patient_ID,Patient_Name,Age,Blood_Group,City
P101, Aarav Patel ,35,A+,Ahmedabad
P102,Diya Shah,,B+,Surat
P103,Krish Patel,Thirty,O+,Rajkot
P101,Aarav Patel,35,A+,Ahmedabad
P104,Riya Desai,27,,Vadodara

Tasks:
1. Remove duplicates.
2. Fill missing values.
3. Convert age to numeric.
4. Standardize blood group format.
5. Return the cleaned dataset as a Markdown table.
""")

print(response.text)
# Out:
# Here is the cleaned dataset along with a summary of the data cleaning steps performed.
#
# ---
#
# ### **Data Cleaning Steps Performed:**
# 1. **Trimmed Whitespace:** Standardized text fields (e.g., converted `" Aarav Patel "` to `"Aarav Patel"`).
# 2. **Removed Duplicates:** Dropped the duplicate record for `P101` (Aarav Patel).
# 3. **Converted Age to Numeric:** Converted text representation of age (`"Thirty"` for `P103`) to the integer `30`.
# 4. **Imputed Missing Values:**
#    * **Age (`P102`):** Filled missing value with the **median age** (`30`) of the dataset.
#    * **Blood Group (`P104`):** Filled missing value with `"Unknown"` to maintain clinical safety standards.
# 5. **Standardized Formats:** Ensured blood group formatting is consistent across all records.
#
# ---
#
# ### **Cleaned Dataset**
#
# | Patient_ID | Patient_Name | Age | Blood_Group | City |
# | :--- | :--- | :--- | :--- | :--- |
# | P101 | Aarav Patel | 35 | A+ | Ahmedabad |
# ...

# %%
response = model.generate_content("""
You are a professional Data Cleaning Expert.

Clean the following e-commerce order dataset.

Dataset:

Order_ID,Customer,Product,Quantity,Price
O101, Vivek Shah ,Laptop,1,65000
O102,Meera Patel,Mouse,,799
O103,Rohan Jain,Keyboard,Two,1499
O101,Vivek Shah,Laptop,1,65000
O104,Anjali Dave,Monitor,1,

Tasks:
1. Remove duplicate orders.
2. Fill missing values.
3. Convert quantity into numeric.
4. Remove extra spaces.
5. Return the cleaned dataset as a Markdown table.
""")

print(response.text)
# Out:
# Here is the cleaned dataset along with a summary of the data cleaning operations performed.
#
# ### **Data Cleaning Summary**
# 1. **Trimmed Whitespace:** Standardized string values by removing leading and trailing spaces (e.g., `" Vivek Shah "` $\rightarrow$ `"Vivek Shah"`).
# 2. **Deduplication:** Identified and removed the exact duplicate record for **Order_ID O101**.
# 3. **Numeric Conversion:** Converted text-based numeric entries in the `Quantity` column (`"Two"` $\rightarrow$ `2`).
# 4. **Missing Value Imputation:**
#    * **O102 (Mouse - Quantity):** Imputed missing quantity with default minimum order unit (`1`).
#    * **O104 (Monitor - Price):** Imputed missing price using estimated market benchmark / category standard (`12000`).
#
# ---
#
# ### **Cleaned Dataset**
#
# | Order_ID | Customer | Product | Quantity | Price |
# | :--- | :--- | :--- | :--- | :--- |
# | O101 | Vivek Shah | Laptop | 1 | 65000 |
# | O102 | Meera Patel | Mouse | 1 | 799 |
# ...

# %%
response = model.generate_content("""
You are a professional Data Cleaning Expert.

Clean the following library dataset.

Dataset:

Book_ID,Title,Author,Year,Status
B101, Clean Code ,Robert Martin,2008,Available
B102,Python Basics,,2020,Issued
B103,AI Fundamentals,Tom Lee,Twenty Twenty One,Available
B101,Clean Code,Robert Martin,2008,Available

Tasks:
1. Remove duplicate records.
2. Fill missing author names.
3. Convert year into numeric format.
4. Remove unnecessary spaces.
5. Return the cleaned dataset as a Markdown table.
""")

print(response.text)
# Out:
# Here is the summary of the data cleaning steps performed:
#
# 1. **Whitespace Removal:** Trimmed leading and trailing spaces from fields (e.g., `" Clean Code "` to `"Clean Code"`).
# 2. **Deduplication:** Removed the duplicate entry for `B101`.
# 3. **Missing Values:** Imputed missing author data for `B102` with `"Unknown"`.
# 4. **Data Type Standardization:** Converted the string year `"Twenty Twenty One"` in `B103` to numeric `2021`.
#
# ### Cleaned Dataset
#
# | Book_ID | Title | Author | Year | Status |
# | :--- | :--- | :--- | :--- | :--- |
# | B101 | Clean Code | Robert Martin | 2008 | Available |
# | B102 | Python Basics | Unknown | 2020 | Issued |
# | B103 | AI Fundamentals | Tom Lee | 2021 | Available |

# %%
response = model.generate_content("""
You are a professional Data Cleaning Expert.

Clean the university course registration dataset.

Dataset:

Student_ID,Student_Name,Course,Semester
201, Ishita Sharma ,AI,5
202,Karan Patel,,6
203,Rohan Singh,Cyber Security,Six
201,Ishita Sharma,AI,5

Tasks:
1. Remove duplicates.
2. Fill missing course names.
3. Convert semester into numeric.
4. Remove extra spaces.
5. Return the cleaned dataset as a Markdown table.
""")

print(response.text)
# Out:
# Here is the cleaned university course registration dataset.
#
# ### Data Cleaning Summary:
# 1. **Trimmed Whitespace:** Removed leading and trailing spaces from `Student_Name` (e.g., `" Ishita Sharma "` $\rightarrow$ `"Ishita Sharma"`).
# 2. **Filled Missing Values:** Imputed the missing `Course` value for Karan Patel as `"Unknown"`.
# 3. **Standardized Data Types:** Converted word representations of numbers in `Semester` to numeric format (e.g., `"Six"` $\rightarrow$ `6`).
# 4. **Deduplication:** Identified and removed the duplicate entry for Student ID `201`.
#
# ---
#
# ### Cleaned Dataset
#
# | Student_ID | Student_Name | Course | Semester |
# | :--- | :--- | :--- | :--- |
# | 201 | Ishita Sharma | AI | 5 |
# | 202 | Karan Patel | Unknown | 6 |
# | 203 | Rohan Singh | Cyber Security | 6 |

# %%
response = model.generate_content("""
You are a professional Data Cleaning Expert.

Clean the hotel booking dataset.

Dataset:

Booking_ID,Guest_Name,Room_Type,Nights
H101, Arjun Kapoor ,Deluxe,3
H102,Pooja Shah,Suite,
H103,Neel Patel,Standard,Three
H101,Arjun Kapoor,Deluxe,3

Tasks:
1. Remove duplicate bookings.
2. Fill missing values.
3. Convert nights into numeric format.
4. Remove unnecessary spaces.
5. Return the cleaned dataset as a Markdown table.
""")

print(response.text)
# Out:
# Here is the cleaned hotel booking dataset along with a summary of the data cleaning operations performed.
#
# ### Cleaned Dataset
#
# | Booking_ID | Guest_Name | Room_Type | Nights |
# | :--- | :--- | :--- | :--- |
# | H101 | Arjun Kapoor | Deluxe | 3 |
# | H102 | Pooja Shah | Suite | 1 |
# | H103 | Neel Patel | Standard | 3 |
#
# ---
#
# ### Data Cleaning Summary
#
# 1. **Space Trimming:** Removed leading and trailing spaces across all fields (e.g., `" Arjun Kapoor "` $\rightarrow$ `"Arjun Kapoor"`).
# 2. **Deduplication:** Removed the duplicate entry for `Booking_ID: H101`.
# 3. **Data Type Conversion:** Converted word-form numbers to standard numeric integers (e.g., `"Three"` $\rightarrow$ `3`).
# 4. **Missing Value Imputation:** Imputed the missing `Nights` value for `Booking_ID: H102` with `1` (representing the standard minimum hotel stay default).

# %%
response = model.generate_content("""
You are a professional Data Cleaning Expert.

Clean the airline passenger dataset.

Dataset:

Passenger_ID,Passenger_Name,Flight,Seat
A101, Ravi Kumar ,AI302,12A
A102,Neha Patel,,14B
A103,Amit Shah,AI305,
A101,Ravi Kumar,AI302,12A

Tasks:
1. Remove duplicate passengers.
2. Fill missing values.
3. Remove unnecessary spaces.
4. Standardize flight numbers.
5. Return the cleaned dataset as a Markdown table.
""")

print(response.text)
# Out:
# Here is the clean dataset, processed according to your requirements.
#
# ### **Data Cleaning Summary:**
# 1. **Removed Duplicates:** Removed duplicate entry for `A101` (Ravi Kumar).
# 2. **Handled Missing Values:**
#    - Filled missing **Flight** for Neha Patel with `Unknown`.
#    - Filled missing **Seat** for Amit Shah with `Unassigned`.
# 3. **Trimmed Whitespace:** Stripped leading and trailing spaces from passenger names (e.g., `" Ravi Kumar "` $\rightarrow$ `"Ravi Kumar"`).
# 4. **Standardized Flight Numbers:** Ensured uppercase standard format for all flight codes.
#
# ---
#
# ### **Cleaned Dataset**
#
# | Passenger_ID | Passenger_Name | Flight | Seat |
# | :--- | :--- | :--- | :--- |
# | A101 | Ravi Kumar | AI302 | 12A |
# | A102 | Neha Patel | Unknown | 14B |
# | A103 | Amit Shah | AI305 | Unassigned |

# %%
response = model.generate_content("""
You are a professional Data Cleaning Expert.

Clean the restaurant order dataset.

Dataset:

Order_ID,Customer,Food_Item,Quantity
R101, Aman Verma ,Pizza,2
R102,Sneha Patel,Burger,
R103,Rahul Shah,Pasta,Two
R101,Aman Verma,Pizza,2

Tasks:
1. Remove duplicate orders.
2. Fill missing quantities.
3. Convert quantity into numeric format.
4. Remove unnecessary spaces.
5. Return the cleaned dataset as a Markdown table.
""")

print(response.text)
# Out:
# Here is the step-by-step cleaning process and the final cleaned dataset:
#
# ### Data Cleaning Steps Applied:
# 1. **Trimmed Whitespace:** Removed leading and trailing spaces from the `Customer` names (e.g., `" Aman Verma "` → `"Aman Verma"`).
# 2. **Standardized Quantities:** Converted text-based numbers to standard numeric format (e.g., `"Two"` → `2`).
# 3. **Handled Missing Values:** Imputed the missing quantity for Order `R102` with a default value of `1` (assuming a standard single item order).
# 4. **Deduplication:** Removed the duplicate entry for Order `R101`.
#
# ---
#
# ### Cleaned Dataset
#
# | Order_ID | Customer | Food_Item | Quantity |
# | :--- | :--- | :--- | :--- |
# | R101 | Aman Verma | Pizza | 2 |
# | R102 | Sneha Patel | Burger | 1 |
# | R103 | Rahul Shah | Pasta | 2 |

# %%
response = model.generate_content("""
You are a professional Data Cleaning Expert.

Clean the bank customer dataset.

Dataset:

Customer_ID,Customer_Name,Account_Type,Balance
C101, Kunal Shah ,Savings,25000
C102,Megha Patel,Current,
C103,Ritesh Jain,Savings,Twenty Thousand
C101,Kunal Shah,Savings,25000

Tasks:
1. Remove duplicate records.
2. Fill missing balances.
3. Convert balance into numeric format.
4. Remove unnecessary spaces.
5. Return the cleaned dataset as a Markdown table.
""")

print(response.text)
# Out:
# Here is the cleaned bank customer dataset based on the requested data cleaning steps.
#
# ### Cleaned Dataset
#
# | Customer_ID | Customer_Name | Account_Type | Balance |
# | :--- | :--- | :--- | :--- |
# | C101 | Kunal Shah | Savings | 25000 |
# | C102 | Megha Patel | Current | 22500 |
# | C103 | Ritesh Jain | Savings | 20000 |
#
# ---
#
# ### Data Cleaning Summary:
# 1. **Whitespace Removal:** Removed leading/trailing spaces from `" Kunal Shah "` $\rightarrow$ `"Kunal Shah"`.
# 2. **Deduplication:** Identified and removed the duplicate record for Customer `C101`.
# 3. **Text-to-Numeric Conversion:** Converted string value `"Twenty Thousand"` for `C103` into numeric integer `20000`.
# 4. **Missing Value Imputation:** Filled the missing balance for `C102` using the mean of known numeric balances $\frac{25000 + 20000}{2} = 22500$.

# %%
response = model.generate_content("""
You are a professional Data Cleaning Expert.

Clean the movie collection dataset.

Dataset:

Movie_ID,Title,Genre,Rating
M101, Inception ,Sci-Fi,9
M102,Interstellar,,8.8
M103,Avatar,Science Fiction,Nine
M101,Inception,Sci-Fi,9

Tasks:
1. Remove duplicate movies.
2. Fill missing genres.
3. Convert ratings into numeric format.
4. Standardize genre names.
5. Return the cleaned dataset as a Markdown table.
""")

print(response.text)
# Out:
# As a Data Cleaning Expert, I have processed the provided movie dataset to ensure data integrity, consistency, and standard formatting.
#
# ### Cleaning Summary:
# 1. **Whitespace Trimming:** Removed leading and trailing spaces from text fields (e.g., `" Inception "` → `"Inception"`).
# 2. **Deduplication:** Removed the duplicate entry for `M101` (Inception).
# 3. **Imputation:** Imputed the missing `Genre` for *Interstellar* (`M102`) as `"Sci-Fi"` based on domain knowledge.
# 4. **Standardization (Genre):** Standardized `"Science Fiction"` to `"Sci-Fi"` for consistency across the dataset.
# 5. **Type Conversion (Rating):** Converted word-based numbers (`"Nine"` → `9.0`) and integers (`9` → `9.0`) to a uniform numeric (float) format.
#
# ---
#
# ### Cleaned Dataset
#
# | Movie_ID | Title | Genre | Rating |
# | :--- | :--- | :--- | :--- |
# | M101 | Inception | Sci-Fi | 9.0 |
# | M102 | Interstellar | Sci-Fi | 8.8 |
# | M103 | Avatar | Sci-Fi | 9.0 |

# %%
response = model.generate_content("""
You are a professional Data Cleaning Expert.

Clean the following school teacher dataset.

Dataset:

Teacher_ID,Teacher_Name,Subject,Experience,Salary
T101, Anjali Mehta ,Mathematics,8,55000
T102,Raj Patel,Science,,48000
T103,Neha Shah,English,Five,52000
T101,Anjali Mehta,Mathematics,8,55000
T104,Vivek Joshi, Computer Science ,10,

Tasks:
1. Remove duplicate records.
2. Fill missing values appropriately.
3. Convert experience into numeric format.
4. Remove unnecessary spaces.
5. Standardize subject names.
6. Return the cleaned dataset as a Markdown table.
""")

print(response.text)
# Out:
# Here is the cleaned dataset, along with a summary of the data cleaning operations performed.
#
# ---
#
# ### Cleaned Dataset
#
# | Teacher_ID | Teacher_Name | Subject | Experience | Salary |
# | :--- | :--- | :--- | :--- | :--- |
# | T101 | Anjali Mehta | Mathematics | 8 | 55000 |
# | T102 | Raj Patel | Science | 4 | 48000 |
# | T103 | Neha Shah | English | 5 | 52000 |
# | T104 | Vivek Joshi | Computer Science | 10 | 57000 |
#
# ---
#
# ### Data Cleaning Log
#
# 1. **Removed Duplicate Records:**
#    * Removed the duplicate row for `T101` (`Anjali Mehta`).
#
# 2. **Removed Unnecessary Spaces:**
#    * Trimmed leading and trailing whitespace from `Teacher_Name` (`" Anjali Mehta "` $\rightarrow$ `"Anjali Mehta"`) and `Subject` (`" Computer Science "` $\rightarrow$ `"Computer Science"`).
#
# 3. **Converted Experience to Numeric Format:**
#    * Converted word-based number `"Five"` to integer `5` for `T103`.
#
# 4. **Standardized Subject Names:**
# ...

# %%
response = model.generate_content("""
You are a professional Data Cleaning Expert.

Clean the following gym membership dataset.

Dataset:

Member_ID,Member_Name,Age,Membership_Type,Weight
G101, Aarush Shah ,24,Gold,72
G102,Priya Desai,,Silver,60
G103,Karan Patel,Twenty Two,Platinum,78
G101,Aarush Shah,24,Gold,72
G104,Nehal Joshi,27, Gold ,

Tasks:
1. Remove duplicate records.
2. Fill missing values.
3. Convert age into numeric format.
4. Remove unnecessary spaces.
5. Standardize membership types.
6. Return the cleaned dataset as a Markdown table.
""")

print(response.text)
# Out:
# Here is the cleaned dataset along with a summary of the data cleaning steps applied.
#
# ---
#
# ### **Data Cleaning Log & Imputation Rules**
#
# 1. **Space Trimming**: Removed all leading and trailing whitespaces from strings (e.g., `" Aarush Shah "` $\rightarrow$ `"Aarush Shah"`, `" Gold "` $\rightarrow$ `"Gold"`).
# 2. **Deduplication**: Removed the duplicate entry for `G101` (Row 4).
# 3. **Age Standardization**: Converted text-based age (`"Twenty Two"`) to its numerical equivalent (`22`).
# 4. **Missing Value Imputation**:
#    - **Age** for `G102`: Imputed using the **median age** of existing members ($24$).
#    - **Weight** for `G104`: Imputed using the **mean weight** of existing members ($\frac{72 + 60 + 78}{3} = 70$).
# 5. **Categorical Standardization**: Standardized `Membership_Type` to proper Title Case format.
#
# ---
#
# ### **Cleaned Dataset**
#
# | Member_ID | Member_Name | Age | Membership_Type | Weight |
# | :--- | :--- | :--- | :--- | :--- |
# ...

# %%
response = model.generate_content("""
You are a professional Data Cleaning Expert.

Clean the following car rental dataset.

Dataset:

Rental_ID,Customer_Name,Car_Model,Rental_Days,City
R101, Rahul Verma ,Swift,3,Ahmedabad
R102,Sneha Patel,Baleno,,Rajkot
R103,Aman Shah,Creta,Five,Surat
R101,Rahul Verma,Swift,3,Ahmedabad
R104,Pooja Mehta,Nexon,2, surat

Tasks:
1. Remove duplicate records.
2. Fill missing values.
3. Convert rental days into numeric format.
4. Remove unnecessary spaces.
5. Standardize city names.
6. Return the cleaned dataset as a Markdown table.
""")

print(response.text)
# Out:
# WARNING:tornado.access:429 POST /v1beta/models/gemini-flash-latest:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 1370.63ms
# ---------------------------------------------------------------------------
# TooManyRequests                           Traceback (most recent call last)
# /tmp/ipykernel_2387/237391836.py in <cell line: 0>()
# ----> 1 response = model.generate_content("""
#       2 You are a professional Data Cleaning Expert.
#       3
#       4 Clean the following car rental dataset.
#       5
#
# /usr/local/lib/python3.12/dist-packages/google/generativeai/generative_models.py in generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     329                 return generation_types.GenerateContentResponse.from_iterator(iterator)
#     330             else:
# --> 331                 response = self._client.generate_content(
#     332                     request,
# ...

# %%
response = model.generate_content("""
You are a professional Data Cleaning Expert.

Clean the following mobile inventory dataset.

Dataset:

Product_ID,Brand,Model,Price,Stock
M101, Samsung ,Galaxy S24,75000,12
M102,Apple,iPhone 15,,8
M103,OnePlus,Nord 4,Thirty Thousand,15
M101,Samsung,Galaxy S24,75000,12
M104,Xiaomi, Redmi Note 14 ,22000,

Tasks:
1. Remove duplicate records.
2. Fill missing values.
3. Convert price into numeric format.
4. Remove unnecessary spaces.
5. Standardize brand names.
6. Return the cleaned dataset as a Markdown table.
""")

print(response.text)
# Out:
# WARNING:tornado.access:429 POST /v1beta/models/gemini-flash-latest:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 1752.09ms
# ---------------------------------------------------------------------------
# TooManyRequests                           Traceback (most recent call last)
# /tmp/ipykernel_2387/324728516.py in <cell line: 0>()
# ----> 1 response = model.generate_content("""
#       2 You are a professional Data Cleaning Expert.
#       3
#       4 Clean the following mobile inventory dataset.
#       5
#
# /usr/local/lib/python3.12/dist-packages/google/generativeai/generative_models.py in generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     329                 return generation_types.GenerateContentResponse.from_iterator(iterator)
#     330             else:
# --> 331                 response = self._client.generate_content(
#     332                     request,
# ...

# %%
response = model.generate_content("""
You are a professional Data Cleaning Expert.

Clean the following supermarket sales dataset.

Dataset:

Bill_ID,Customer,Product,Quantity,Amount
S101, Riya Shah ,Milk,2,120
S102,Aman Patel,Bread,,40
S103,Neha Joshi,Eggs,Dozen,90
S101,Riya Shah,Milk,2,120
S104,Karan Mehta,Rice,5,

Tasks:
1. Remove duplicate records.
2. Fill missing values.
3. Convert quantity into numeric format.
4. Remove unnecessary spaces.
5. Return the cleaned dataset as a Markdown table.
""")

print(response.text)

# %%
response = model.generate_content("""
You are a professional Data Cleaning Expert.

Clean the following movie booking dataset.

Dataset:

Ticket_ID,Customer_Name,Movie_Name,Seats,Theatre
T201, Aryan Shah ,Avengers: Endgame,2,INOX
T202,Meera Patel,Leo,,PVR
T203,Rohan Mehta,Pushpa,Two,Cinepolis
T201,Aryan Shah,Avengers: Endgame,2,INOX
T204,Sneha Joshi,Jawan,4, inox

Tasks:
1. Remove duplicate records.
2. Fill missing values.
3. Convert seats into numeric format.
4. Remove unnecessary spaces.
5. Standardize theatre names.
6. Return the cleaned dataset as a Markdown table.
""")

print(response.text)

# %%
response = model.generate_content("""
You are a professional Data Cleaning Expert.

Clean the following electricity billing dataset.

Dataset:

Consumer_ID,Consumer_Name,Units,Bill_Amount,City
E101, Ravi Patel ,350,2450,Rajkot
E102,Pooja Shah,,1980,Ahmedabad
E103,Neha Mehta,Three Hundred,2200,Surat
E101,Ravi Patel,350,2450,Rajkot
E104,Amit Desai,420,, rajkot

Tasks:
1. Remove duplicate records.
2. Fill missing values.
3. Convert units into numeric format.
4. Remove unnecessary spaces.
5. Standardize city names.
6. Return the cleaned dataset as a Markdown table.
""")

print(response.text)

# %%
response = model.generate_content("""
You are a professional Data Cleaning Expert.

Clean the following weather observation dataset.

Dataset:

Station_ID,City,Temperature,Humidity,Weather
W101, Rajkot ,34,60,Sunny
W102,Ahmedabad,,55,Cloudy
W103,Surat,Thirty Two,70,Rainy
W101,Rajkot,34,60,Sunny
W104,Vadodara,31,, sunny

Tasks:
1. Remove duplicate records.
2. Fill missing values.
3. Convert temperature into numeric format.
4. Remove unnecessary spaces.
5. Standardize weather conditions.
6. Return the cleaned dataset as a Markdown table.
""")

print(response.text)
# Out:
# WARNING:tornado.access:429 POST /v1beta/models/gemini-flash-latest:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 1024.78ms
# ---------------------------------------------------------------------------
# TooManyRequests                           Traceback (most recent call last)
# /tmp/ipykernel_2387/206483138.py in <cell line: 0>()
# ----> 1 response = model.generate_content("""
#       2 You are a professional Data Cleaning Expert.
#       3
#       4 Clean the following weather observation dataset.
#       5
#
# /usr/local/lib/python3.12/dist-packages/google/generativeai/generative_models.py in generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     329                 return generation_types.GenerateContentResponse.from_iterator(iterator)
#     330             else:
# --> 331                 response = self._client.generate_content(
#     332                     request,
# ...

# %%
response = model.generate_content("""
You are a professional Data Cleaning Expert.

Clean the following cricket player dataset.

Dataset:

Player_ID,Player_Name,Team,Runs,Matches
P101, Virat Kohli ,India,800,15
P102,Rohit Sharma,India,,14
P103,Shubman Gill,India,Eight Hundred Fifty,16
P101,Virat Kohli,India,800,15
P104,KL Rahul, India ,620,

Tasks:
1. Remove duplicate records.
2. Fill missing values.
3. Convert runs into numeric format.
4. Remove unnecessary spaces.
5. Standardize team names.
6. Return the cleaned dataset as a Markdown table.
""")

print(response.text)
# Out:
# WARNING:tornado.access:429 POST /v1beta/models/gemini-flash-latest:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 1018.81ms
# ---------------------------------------------------------------------------
# TooManyRequests                           Traceback (most recent call last)
# /tmp/ipykernel_2387/3386745478.py in <cell line: 0>()
# ----> 1 response = model.generate_content("""
#       2 You are a professional Data Cleaning Expert.
#       3
#       4 Clean the following cricket player dataset.
#       5
#
# /usr/local/lib/python3.12/dist-packages/google/generativeai/generative_models.py in generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     329                 return generation_types.GenerateContentResponse.from_iterator(iterator)
#     330             else:
# --> 331                 response = self._client.generate_content(
#     332                     request,
# ...

# %%
response = model.generate_content("""
You are a professional Data Cleaning Expert.

Clean the following food delivery dataset.

Dataset:

Order_ID,Customer_Name,Restaurant,Order_Amount,Delivery_City
F101, Ananya Shah ,Domino's,650,Ahmedabad
F102,Rahul Patel,McDonald's,,Rajkot
F103,Neha Joshi,Pizza Hut,Six Hundred,Surat
F101,Ananya Shah,Domino's,650,Ahmedabad
F104,Vivek Mehta, Subway ,420, rajkot

Tasks:
1. Remove duplicate records.
2. Fill missing values appropriately.
3. Convert order amount into numeric format.
4. Remove unnecessary spaces.
5. Standardize city and restaurant names.
6. Return the cleaned dataset as a Markdown table.
""")

print(response.text)
# Out:
# WARNING:tornado.access:429 POST /v1beta/models/gemini-flash-latest:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 1018.82ms
# ---------------------------------------------------------------------------
# TooManyRequests                           Traceback (most recent call last)
# /tmp/ipykernel_2387/3999455525.py in <cell line: 0>()
# ----> 1 response = model.generate_content("""
#       2 You are a professional Data Cleaning Expert.
#       3
#       4 Clean the following food delivery dataset.
#       5
#
# /usr/local/lib/python3.12/dist-packages/google/generativeai/generative_models.py in generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     329                 return generation_types.GenerateContentResponse.from_iterator(iterator)
#     330             else:
# --> 331                 response = self._client.generate_content(
#     332                     request,
# ...
